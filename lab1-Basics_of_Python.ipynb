# %%
#task 1
print("hello world")
# Out:
# hello world

# %%
#task 2
print(54+56)
# Out:
# 110

# %%
#task 3
season="Fall"
year =2022
print(season)
print(year)
# Out:
# Fall
# 2022

# %%
#task 4
name=input("Enter your name: ")
print("Your name is",name)
# Out:
# Enter your name: Rida
# Your name is Rida

# %%
#task 5 with sep
M=int(input("Enter a number: "))
N=int(input("Enter another number: "))
O=M**N
print(M,"^",N,": ",O,sep="")
# Out:
# Enter a number: 2
# Enter another number: 3
# 2^3: 8

# %%
#task 5 with .format
M=int(input("Enter a number: "))
N=int(input("Enter another number: "))
O=M**N
print("{}^{}: {}".format(M,N,O))
# Out:
# Enter a number: 2
# Enter another number: 3
# 2^3: 8

# %%
#task 6
a=int(input("Enter a number: "))
b=a%4
c=a-b
print(c)
# Out:
# Enter a number: 23
# 20

# %%
#task 7
A=int(input("Enter a number: "))
B=int(input("Enter another number: "))
C=int(input("Enter another number: "))
D=float(input("Enter another number: "))
total=(A**C)+(B*A)-(D/3)
print(int(total))
# Out:
# Enter a number: 9
# Enter another number: 100
# Enter another number: 1
# Enter another number: 3.7
# 907

# %%
#task 8
chocolates=int(input("Enter chocolate amount: "))
friend=chocolates//3
me=chocolates%3
print("Each friend will receive",friend,"chocolates")
print("The number of remaining chocolates is",me)

# %%
#task 9
M=input("")
N=input("")
print(N+M)
# Out:
# python
# 3
# 3python

# %%
#task 10
text=input("Enter a text: ")
print(text[0])
# Out:
# Enter a text: the quick brown fox jumps over the lazy dog
# t

# %%
#task 11
num=int(input("Enter a number: "))
if(num%2==0):
  print("True")
else:
  print("False")
# Out:
# Enter a number: 33
# False
